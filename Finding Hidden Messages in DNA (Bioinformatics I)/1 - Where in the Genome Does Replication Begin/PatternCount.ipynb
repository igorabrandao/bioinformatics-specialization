# %% [markdown]
# IMPORT THE INPUT FILE

# %%
# Import the Google Colab drive lib
from google.colab import drive
drive.mount('/content/drive')

# Read the input file
input_path = open('/content/drive/My Drive/UFRN/10 - Cursos online/Finding Hidden Messages in DNA (Bioinformatics I)/1 - Where in the Genome Does Replication Begin/dataset_2_7.txt', 'r')
input = input_path.read()

# Print the input
print(input)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ...
# TTGCGTCTT

# %% [markdown]
# THE CODE LOGIC BEGINS HERE!

# %%
# Define the PatternCount function
def PatternCount(input_, pattern_):
  occurrences = 0
  pattern_size = len(pattern_)

  for idx, chr in enumerate(input_):
    if input_[idx:(idx+pattern_size)] == pattern_:
      occurrences+=1
  return occurrences

# %%
# ======================================
# Test section
# ClumpFinding(Genome_, k_, t_, L_):
# ======================================
# Test 1
output = PatternCount(input, "TTGCGTCTT")
# Print the output (minus the input in the second line of file)
print(output - 1)

# Test 2
output2 = PatternCount("ACTGTACGATGATGTGTGTCAAAG", "TGT")
print(output2)
# Out:
# 40
# 4
